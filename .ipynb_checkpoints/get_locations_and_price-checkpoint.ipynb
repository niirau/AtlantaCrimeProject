# %%
import pandas as pd
import requests
import pyodbc
import sqlalchemy

# %%
locations = pd.read_csv('datasets\med_sale_price.csv', sep='\t')

# %%
locations
# Out:
#                             Unnamed: 0 Month of Period End  \
# 0                               Region        January 2012
# 1             Atlanta, GA - Adair Park                $27K
# 2             Atlanta, GA - Adams Park                $28K
# 3             Atlanta, GA - Adamsville                $11K
# 4            Atlanta, GA - Almond Park                $14K
# ..                                 ...                 ...
# 216  Atlanta, GA - Wilson Mill Meadows                $18K
# 217     Atlanta, GA - Wisteria Gardens                 NaN
# 218            Atlanta, GA - Woodfield                 NaN
# 219       Atlanta, GA - Woodland Hills                $81K
# 220              Atlanta, GA - Wyngate                 NaN
#
#     Month of Period End.1 Month of Period End.2 Month of Period End.3  \
# 0           February 2012            March 2012            April 2012
# 1                    $25K                  $25K                  $15K
# ...

# %%
locations.iloc[0,:]
# Out:
# Unnamed: 0                         Region
# Month of Period End          January 2012
# Month of Period End.1       February 2012
# Month of Period End.2          March 2012
# Month of Period End.3          April 2012
#                                 ...
# Month of Period End.114         July 2021
# Month of Period End.115       August 2021
# Month of Period End.116    September 2021
# Month of Period End.117      October 2021
# Month of Period End.118     November 2021
# Name: 0, Length: 120, dtype: object

# %%
print(text['data'][0])
# Out:
# {'ID Race': 0, 'Race': 'Total', 'ID Year': 2019, 'Year': '2019', 'Household Income by Race': 65712, 'Household Income by Race Moe': 118, 'Geography': 'United States', 'ID Geography': '01000US', 'Slug Geography': 'united-states'}

# %%
data = pd.DataFrame(text['data'])

# %%
data.Race.unique
# Out:
# <bound method Series.unique of 0                   Total
# 1                   White
# 2                   Black
# 3         Native American
# 4                   Asian
#               ...
# 387      Pacific Islander
# 388                 Other
# 389           Two Or More
# 390    White Non-Hispanic
# 391              Hispanic
# Name: Race, Length: 392, dtype: object>

# %%
data.head(20)
# Out:
#     ID Race                Race  ID Year  Year  Household Income by Race  \
# 0         0               Total     2019  2019                     65712
# 1         1               White     2019  2019                     69823
# 2         2               Black     2019  2019                     43862
# 3         3     Native American     2019  2019                     45476
# 4         4               Asian     2019  2019                     93759
# 5         5    Pacific Islander     2019  2019                     66464
# 6         6               Other     2019  2019                     53097
# 7         7         Two Or More     2019  2019                     62085
# 8         8  White Non-Hispanic     2019  2019                     71664
# 9         9            Hispanic     2019  2019                     55658
# 10        0               Total     2019  2019                     61980
# 11        1               White     2019  2019                     70832
# ...

# %%
data.to_csv('datasets/modified/incomeRace.csv')

# %%
data.to_sql('race', cnxn)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# ProgrammingError: ('42S02', "[42S02] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Invalid object name 'sqlite_master'. (208) (SQLExecDirectW); [42S02] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Statement(s) could not be prepared. (8180)")
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\HKON~1\AppData\Local\Temp/ipykernel_13612/3308241105.py in <module>
# ----> 1 data.to_sql('race', cnxn)
#
# ...
