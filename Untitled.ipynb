# %%
import pandas as pd
import sys

# %%
crime = pd.read_csv('datasets/atlcrime.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
crime.head()
# Out:
#    Unnamed: 0                 crime     number        date  \
# 0           0   LARCENY-NON VEHICLE  103040029  10/31/2010
# 1           1            AUTO THEFT  103040061  10/31/2010
# 2           2  LARCENY-FROM VEHICLE  103040169  10/31/2010
# 3           3            AUTO THEFT  103040174  10/31/2010
# 4           4   LARCENY-NON VEHICLE  103040301  10/31/2010
#
#                                   location beat        neighborhood npu  \
# 0                         610 SPRING ST NW  509            Downtown   M
# 1                            850 OAK ST SW  401            West End   T
# 2                1344 METROPOLITAN PKWY SW  301  Capitol View Manor   X
# 3                         1752 PRYOR RD SW  307      Betmar LaVilla   Y
# 4  JOHN WESLEY DOBBS AVE NE / CORLEY ST NE  604     Old Fourth Ward   M
#
#         lat      long
# 0  33.77101 -84.38895
# 1  33.74057 -84.41680
# 2  33.71803 -84.40774
# 3  33.70731 -84.39674
# 4  33.75947 -84.36626

# %%
crime.rename(columns={crime.columns[0]:"counter"}, inplace=True)

# %%
crime
# Out:
#         counter                 crime       number        date  \
# 0             0   LARCENY-NON VEHICLE    103040029  10/31/2010
# 1             1            AUTO THEFT    103040061  10/31/2010
# 2             2  LARCENY-FROM VEHICLE    103040169  10/31/2010
# 3             3            AUTO THEFT    103040174  10/31/2010
# 4             4   LARCENY-NON VEHICLE    103040301  10/31/2010
# ...         ...                   ...          ...         ...
# 270683   270683    BURGLARY-RESIDENCE     92442142  09/01/2009
# 270684   270684  LARCENY-FROM VEHICLE     92442164  09/01/2009
# 270685   270685   LARCENY-NON VEHICLE     92448045  09/01/2009
# 270686   270686   LARCENY-NON VEHICLE     92440866  09/01/2009
# 270687   270687              HOMICIDE  92440372058  09/01/2009
#
#                                        location beat        neighborhood  npu  \
# 0                              610 SPRING ST NW  509            Downtown    M
# ...

# %%
crime.isnull().sum()
# Out:
# counter             0
# crime               0
# number              0
# date                0
# location            2
# beat                0
# neighborhood    11760
# npu              2096
# lat                 0
# long                0
# dtype: int64

# %%
crime.isnull().sum()/crime.count()
# Out:
# counter         0.000000
# crime           0.000000
# number          0.000000
# date            0.000000
# location        0.000007
# beat            0.000000
# neighborhood    0.045418
# npu             0.007804
# lat             0.000000
# long            0.000000
# dtype: float64

# %%
crime[crime.isnull().values]
# Out:
#         counter                 crime     number        date  \
# 90           90   LARCENY-NON VEHICLE  103048029  10/31/2010
# 90           90   LARCENY-NON VEHICLE  103048029  10/31/2010
# 149         149  LARCENY-FROM VEHICLE  103030336  10/30/2010
# 153         153    BURGLARY-RESIDENCE  103030486  10/30/2010
# 160         160   LARCENY-NON VEHICLE  103030700  10/30/2010
# ...         ...                   ...        ...         ...
# 270551   270551            AUTO THEFT   92450525  09/02/2009
# 270570   270570            AUTO THEFT   92450869  09/02/2009
# 270635   270635       BURGLARY-NONRES   92440470  09/01/2009
# 270685   270685   LARCENY-NON VEHICLE   92448045  09/01/2009
# 270685   270685   LARCENY-NON VEHICLE   92448045  09/01/2009
#
#                            location beat neighborhood  npu       lat      long
# 90      CONCOURSE C @10700 SPINE RD   50          NaN  NaN  33.64063 -84.43256
# ...

# %%
crime.rollup[['neighborhood', 'npu']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\HKON~1\AppData\Local\Temp/ipykernel_15096/4098363330.py in <module>
# ----> 1 crime.rollup[['neighborhood', 'npu']]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rollup'

# %%
sys.platform
# Out:
# 'win32'
