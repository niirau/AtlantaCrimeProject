# %%
import pandas as pd

df = pd.read_csv('./datasets/atlcrime.csv')
df
# Out:
#         Unnamed: 0                 crime       number        date  \
# 0                0   LARCENY-NON VEHICLE    103040029  10/31/2010
# 1                1            AUTO THEFT    103040061  10/31/2010
# 2                2  LARCENY-FROM VEHICLE    103040169  10/31/2010
# 3                3            AUTO THEFT    103040174  10/31/2010
# 4                4   LARCENY-NON VEHICLE    103040301  10/31/2010
# ...            ...                   ...          ...         ...
# 270683      270683    BURGLARY-RESIDENCE     92442142  09/01/2009
# 270684      270684  LARCENY-FROM VEHICLE     92442164  09/01/2009
# 270685      270685   LARCENY-NON VEHICLE     92448045  09/01/2009
# 270686      270686   LARCENY-NON VEHICLE     92440866  09/01/2009
# 270687      270687              HOMICIDE  92440372058  09/01/2009
#
#                                        location beat        neighborhood  npu  \
# 0                              610 SPRING ST NW  509            Downtown    M
# ...
